# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("leaf.jpg", cv2.IMREAD_COLOR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
cv2.namedWindow("title", cv2.WINDOW_NORMAL)
cv2.resizeWindow("title", 1920, 1080)
plt.imshow(image)
plt.show()

# %%
image = cv2.imread("leaf.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
ret, thresh1 = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
cv2.namedWindow("title", cv2.WINDOW_NORMAL)
cv2.resizeWindow("title", 1920, 1080)
cv2.imshow("title", thresh1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
max_value = 255
max_type = 4
max_binary_value = 255
trackbar_type = 'Type: \n 0: Binary \n 1: Binary Inverted \n 2: Truncate \n 3: To Zero \n 4: To Zero Inverted'
trackbar_value = 'value'
window_name = "threshold"
def Threshold(val):
    threshold_type = cv2.getTrackbarPos(trackbar_type, window_name)
    threshold_value = cv2.getTrackbarPos(trackbar_value, window_name)
    ret, frame = cv2.threshold(image_gray, threshold_value, max_binary_value, threshold_type)
    cv2.imshow(window_name, frame)

image = cv2.imread("leaf.jpg")
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.resizeWindow(window_name, 1920, 1080)
cv2.createTrackbar(trackbar_type, window_name, 3, max_value, Threshold)
cv2.createTrackbar(trackbar_value, window_name, 0, max_value, Threshold)
Threshold(0)
cv2.waitKey()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-64cb841843c7> in Threshold(val)
#       8     threshold_type = cv2.getTrackbarPos(trackbar_type, window_name)
#       9     threshold_value = cv2.getTrackbarPos(trackbar_value, window_name)
# ---> 10     ret, frame = cv2.threshold(image_gray, threshold_value, max_binary_value, threshold_type)
#      11     cv2.imshow(window_name, frame)
#      12
#
# error: OpenCV(4.2.0) ../modules/imgproc/src/thresh.cpp:1526: error: (-215:Assertion failed) automatic_thresh != (CV_THRESH_OTSU | CV_THRESH_TRIANGLE) in function 'threshold'
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-64cb841843c7> in Threshold(val)
#       8     threshold_type = cv2.getTrackbarPos(trackbar_type, window_name)
# ...

# %%
cap = cv2.VideoCapture("whales_cut.mp4")
count = 0
nframe = cap.get(cv2.CAP_PROP_FRAME_COUNT)
print(nframe)
while cap.isOpened():
    ret, frame = cap.read()
    cv2.imwrite("frame%d.jpg"%count,frame)
    count+=1
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 250.0
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-348655762ac2> in <module>
#       5 while cap.isOpened():
#       6     ret, frame = cap.read()
# ----> 7     cv2.imwrite("frame%d.jpg"%count,frame)
#       8     count+=1
#       9     if cv2.waitKey(10) & 0xFF == ord('q'):
#
# error: OpenCV(4.2.0) ../modules/imgcodecs/src/loadsave.cpp:715: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %%
backsub1 = cv2.createBackgroundSubtractorMOG2()
backsub2 = cv2.createBackgroundSubtractorKNN()
cap = cv2.VideoCapture("whales_cut.mp4")
while True:
    ret, frame = cap.read()
    foreground = backsub2.apply(frame)
    cv2.imshow("foreground", foreground)
    cv2.waitKey(20)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-55fc63d551e2> in <module>
#       4 while True:
#       5     ret, frame = cap.read()
# ----> 6     foreground = backsub2.apply(frame)
#       7     cv2.imshow("foreground", foreground)
#       8     cv2.waitKey(20)
#
# error: OpenCV(4.2.0) ../modules/core/src/rand.cpp:394: error: (-215:Assertion failed) !_mat.empty() in function 'fill'
